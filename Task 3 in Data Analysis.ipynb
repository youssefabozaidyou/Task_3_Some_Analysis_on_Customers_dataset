# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\youss\Desktop\You&.._..&يو\Customers.csv")
df = pd.DataFrame(df)
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %%
df.tail()
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# 1995         Artist                8            7
# 1996         Doctor                7            7
# 1997     Healthcare                9            2
# 1998      Executive                7            2
# 1999  Entertainment                5            2

# %%
df.sample()
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 1433        1434  Female   14              76001                      46
#
#      Profession  Work Experience  Family Size
# 1433     Artist                7            3

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              2000 non-null   int64
#  1   Gender                  2000 non-null   str
#  2   Age                     2000 non-null   int64
#  3   Annual Income ($)       2000 non-null   int64
#  4   Spending Score (1-100)  2000 non-null   int64
#  5   Profession              1965 non-null   str
#  6   Work Experience         2000 non-null   int64
#  7   Family Size             2000 non-null   int64
# dtypes: int64(6), str(2)
# memory usage: 125.1 KB

# %%
df.describe()
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  2000.000000  2000.000000        2000.000000             2000.000000
# mean   1000.500000    48.960000      110731.821500               50.962500
# std     577.494589    28.429747       45739.536688               27.934661
# min       1.000000     0.000000           0.000000                0.000000
# 25%     500.750000    25.000000       74572.000000               28.000000
# 50%    1000.500000    48.000000      110045.000000               50.000000
# 75%    1500.250000    73.000000      149092.750000               75.000000
# max    2000.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      2000.000000  2000.000000
# mean          4.102500     3.768500
# std           3.922204     1.970749
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %%
print(df['Age'].max())
print(df['Age'].min())
# Out:
# 99
# 0

# %%
for i in df.index:
    if df.loc[i, 'Age'] <= 5:
        df.drop(i , inplace=True)
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
df['Profession'] = df['Profession'].fillna('Unknown')

# %%
df.isna().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income ($)         0
# Spending Score (1-100)    0
# Profession                0
# Work Experience           0
# Family Size               0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df['Annual Income ($)'].max())
print(df['Annual Income ($)'].min())
# Out:
# 189974
# 0

# %%
for x in df.index:
    if df.loc[x, 'Annual Income ($)'] <= 1000:
        df.drop(x , inplace=True)
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
print(df['Profession'].value_counts())
# Out:
# Profession
# Artist           582
# Healthcare       320
# Entertainment    217
# Engineer         172
# Doctor           146
# Executive        142
# Lawyer           132
# Marketing         80
# Homemaker         55
# Unknown           33
# Name: count, dtype: int64

# %%
print(df['Work Experience'].max())
# Out:
# 17

# %%
print(df['Work Experience'].min())
# Out:
# 0

# %%
df['Profession'].value_counts()
# Out:
# Profession
# Artist           582
# Healthcare       320
# Entertainment    217
# Engineer         172
# Doctor           146
# Executive        142
# Lawyer           132
# Marketing         80
# Homemaker         55
# Unknown           33
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1879 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              1879 non-null   int64
#  1   Gender                  1879 non-null   str
#  2   Age                     1879 non-null   int64
#  3   Annual Income ($)       1879 non-null   int64
#  4   Spending Score (1-100)  1879 non-null   int64
#  5   Profession              1879 non-null   str
#  6   Work Experience         1879 non-null   int64
#  7   Family Size             1879 non-null   int64
# dtypes: int64(6), str(2)
# memory usage: 196.7 KB

# %%
df['Gender'] = df['Gender'].astype('category')
df['Gender'].info()
# Out:
# <class 'pandas.Series'>
# Index: 1879 entries, 0 to 1999
# Series name: Gender
# Non-Null Count  Dtype
# --------------  -----
# 1879 non-null   category
# dtypes: category(1)
# memory usage: 81.1 KB

# %%
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x=df['Annual Income ($)'])
plt.show()
Q1 = df['Annual Income ($)'].quantile(0.25)
Q3 = df['Annual Income ($)'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['Annual Income ($)'] >= lower_bound) & (df['Annual Income ($)'] <= upper_bound)]

# %%
df['High_Spender'] = df['Spending Score (1-100)'] > 50
print(df['High_Spender'].sum())
# Out:
# 925

# %%
df['Low_Spender'] = df['Spending Score (1-100)'] < 50
print(df['Low_Spender'].sum())
# Out:
# 931

# %%
df['Spending_Ratio'] = df['Spending Score (1-100)'] / df['Annual Income ($)']
print(df['Spending_Ratio'])
# Out:
# 0       0.002600
# 1       0.002314
# 2       0.000070
# 3       0.001305
# 4       0.001053
#           ...
# 1995    0.000217
# 1996    0.000437
# 1997    0.000154
# 1998    0.000022
# 1999    0.000470
# Name: Spending_Ratio, Length: 1879, dtype: float64
